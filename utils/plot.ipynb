# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
from util import load_dataset

# %%
(X_train, y_train), (X_test, y_test) = load_dataset("wafer")
print(X_train.shape, y_train.shape)

plt.plot(X_train[420, :, 0])
plt.show()
# Out:
# (1000, 152, 1) (1000,)

# %%
(X_train, y_train), (X_test, y_test) = load_dataset("wafer", augmentation_type="window_warp", augmentation_ratio=1)
print(X_train.shape, y_train.shape)


plt.plot(X_train[1398, :, 0])
plt.show()
# Out:
# (2000, 152, 1) (2000,)
